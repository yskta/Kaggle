# %% [markdown]
# ## テキスト解析
#
# Spacyによるテキスト解析を行う。
#
# まず、Spacyパッケージをインストールする。

# %%
# !pip install spacy
# !pip install ja-ginza
# Out:
# Collecting spacy
#   Downloading spacy-3.7.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (27 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.10-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.0 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.8-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.4 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.9-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.2 kB)
# Collecting thinc<8.3.0,>=8.2.2 (from spacy)
#   Downloading thinc-8.2.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Downloading srsly-2.4.8-cp311-cp311-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.1.0 (from spacy)
#   Downloading weasel-0.4.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting typer<1.0.0,>=0.3.0 (from spacy)
#   Downloading typer-0.12.3-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (1.10.12)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in /Users/kitagawayoshifumi/.local/lib/python3.11/site-packages (from spacy) (24.0)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy)
#   Downloading langcodes-3.4.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: numpy>=1.19.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (1.26.4)
# Collecting language-data>=1.2 (from langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading language_data-1.2.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/kitagawayoshifumi/.local/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.3.0,>=8.2.2->spacy)
#   Downloading blis-0.7.11-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.3.0,>=8.2.2->spacy)
#   Downloading confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: click>=8.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Collecting shellingham>=1.3.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: rich>=10.11.0 in /opt/anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.3.5)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.1.0->spacy)
#   Downloading cloudpathlib-0.18.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /opt/anaconda3/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jinja2->spacy) (2.1.3)
# Collecting marisa-trie>=0.7.7 (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading marisa_trie-1.2.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.7 kB)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/kitagawayoshifumi/.local/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.0)
# Downloading spacy-3.7.5-cp311-cp311-macosx_11_0_arm64.whl (6.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 10.1 MB/s eta 0:00:00a 0:00:01
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.8-cp311-cp311-macosx_11_0_arm64.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 2.7 MB/s eta 0:00:00
# Downloading langcodes-3.4.0-py3-none-any.whl (182 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.0/182.0 kB 7.6 MB/s eta 0:00:00
# Downloading murmurhash-1.0.10-cp311-cp311-macosx_11_0_arm64.whl (26 kB)
# Downloading preshed-3.0.9-cp311-cp311-macosx_11_0_arm64.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.8/128.8 kB 8.9 MB/s eta 0:00:00
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.4.8-cp311-cp311-macosx_11_0_arm64.whl (488 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.4/488.4 kB 9.5 MB/s eta 0:00:00ta 0:00:01
# Downloading thinc-8.2.5-cp311-cp311-macosx_11_0_arm64.whl (773 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 773.9/773.9 kB 9.7 MB/s eta 0:00:00:00:0100:01
# Downloading typer-0.12.3-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 2.9 MB/s eta 0:00:00
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-0.4.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.3/50.3 kB 5.1 MB/s eta 0:00:00
# Downloading blis-0.7.11-cp311-cp311-macosx_11_0_arm64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 10.1 MB/s eta 0:00:00a 0:00:01
# Downloading cloudpathlib-0.18.1-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 4.3 MB/s eta 0:00:00
# Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Downloading language_data-1.2.0-py3-none-any.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 9.2 MB/s eta 0:00:0000:0100:01m
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading marisa_trie-1.2.0-cp311-cp311-macosx_11_0_arm64.whl (174 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.6/174.6 kB 9.2 MB/s eta 0:00:00
# Installing collected packages: cymem, wasabi, spacy-loggers, spacy-legacy, shellingham, murmurhash, marisa-trie, cloudpathlib, catalogue, blis, srsly, preshed, language-data, typer, langcodes, confection, weasel, thinc, spacy
# Successfully installed blis-0.7.11 catalogue-2.0.10 cloudpathlib-0.18.1 confection-0.1.5 cymem-2.0.8 langcodes-3.4.0 language-data-1.2.0 marisa-trie-1.2.0 murmurhash-1.0.10 preshed-3.0.9 shellingham-1.5.4 spacy-3.7.5 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 thinc-8.2.5 typer-0.12.3 wasabi-1.1.3 weasel-0.4.1
# Collecting ja-ginza
#   Downloading ja_ginza-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: spacy<4.0.0,>=3.4.4 in /opt/anaconda3/lib/python3.11/site-packages (from ja-ginza) (3.7.5)
# Collecting sudachipy<0.7.0,>=0.6.2 (from ja-ginza)
#   Downloading SudachiPy-0.6.8-cp311-cp311-macosx_10_12_universal2.whl.metadata (12 kB)
# Collecting sudachidict-core>=20210802 (from ja-ginza)
#   Downloading SudachiDict_core-20240409-py3-none-any.whl.metadata (2.5 kB)
# Collecting ginza<5.3.0,>=5.2.0 (from ja-ginza)
#   Downloading ginza-5.2.0-py3-none-any.whl.metadata (448 bytes)
# Collecting plac>=1.3.3 (from ginza<5.3.0,>=5.2.0->ja-ginza)
#   Downloading plac-1.4.3-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->ja-ginza) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->ja-ginza) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->ja-ginza) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->ja-ginza) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->ja-ginza) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->ja-ginza) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->ja-ginza) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->ja-ginza) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->ja-ginza) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->ja-ginza) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->ja-ginza) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->ja-ginza) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->ja-ginza) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->ja-ginza) (1.10.12)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->ja-ginza) (3.1.3)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->ja-ginza) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in /Users/kitagawayoshifumi/.local/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->ja-ginza) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->ja-ginza) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy<4.0.0,>=3.4.4->ja-ginza) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /opt/anaconda3/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<4.0.0,>=3.4.4->ja-ginza) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/kitagawayoshifumi/.local/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.4.4->ja-ginza) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.4->ja-ginza) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.4->ja-ginza) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.4->ja-ginza) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.4->ja-ginza) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0.0,>=3.4.4->ja-ginza) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0.0,>=3.4.4->ja-ginza) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->ja-ginza) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->ja-ginza) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /opt/anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->ja-ginza) (13.3.5)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /opt/anaconda3/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy<4.0.0,>=3.4.4->ja-ginza) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /opt/anaconda3/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy<4.0.0,>=3.4.4->ja-ginza) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jinja2->spacy<4.0.0,>=3.4.4->ja-ginza) (2.1.3)
# Requirement already satisfied: marisa-trie>=0.7.7 in /opt/anaconda3/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4.0.0,>=3.4.4->ja-ginza) (1.2.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->ja-ginza) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/kitagawayoshifumi/.local/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->ja-ginza) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->ja-ginza) (0.1.0)
# Downloading ja_ginza-5.2.0-py3-none-any.whl (59.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 9.8 MB/s eta 0:00:00:00:0100:01
# Downloading ginza-5.2.0-py3-none-any.whl (21 kB)
# Downloading SudachiDict_core-20240409-py3-none-any.whl (72.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 MB 8.6 MB/s eta 0:00:0000:0100:01m
# Downloading SudachiPy-0.6.8-cp311-cp311-macosx_10_12_universal2.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 9.2 MB/s eta 0:00:00a 0:00:01m
# Downloading plac-1.4.3-py2.py3-none-any.whl (22 kB)
# Installing collected packages: sudachipy, plac, sudachidict-core, ginza, ja-ginza
# Successfully installed ginza-5.2.0 ja-ginza-5.2.0 plac-1.4.3 sudachidict-core-20240409 sudachipy-0.6.8

# %%
# import spacy package.
import spacy
from spacy import displacy

# %% [markdown]
# ## テキスト解析モデルを読み込む
# Spacyでは、日本語を含む様々な言語のコーパスで学習された解析モデルが利用できる。
# このような学習済みモデルを使うことで、自分でモデルを訓練する必要がない。
# ここでは、日本語解析モデル「ja_ginza」を読み込む。
# もし英語のテキストを解析したい場合は、「en_core_web_sm」などの英語解析モデルも使用できる。

# %%
nlp = spacy.load('ja_ginza')

# %% [markdown]
# ###テキスト解析を行う

# %% [markdown]
# 解析用のテキストを定義する:

# %%
# text = 'いよいよサッカーのワールドカップが始まった。今回の日本代表への期待はこれまで以上に大きい。海外のトップクラブで活躍する選手が多いからだ。'
text = '中国が風力発電機の特許競争力で2023年に初めて首位になった。欧州最大手のベスタスを抱えるデンマークを逆転した。中国勢はコスト削減につながる風車の大型化で技術力を高めており、6割に達する世界シェアのさらなる拡大が見込まれる。太陽光パネルに続き、風力発電機でも価格攻勢を強めており、米欧は脱炭素の関連産業の保護に動き始めた。'

# %% [markdown]
# 先ほど読み込んだテキスト解析モデル（nlp）を使ってテキスト解析を行う：

# %%
doc = nlp(text)

# %% [markdown]
# ## 文分割と単語分割
# 文分割の結果を確認する:

# %%
print("==== 文分割:Text====")
for i, sent in enumerate(doc.sents):
    print(f'{i+1}番目の文：', sent)
# Out:
# ==== 文分割:Text====
# 1番目の文： 中国が風力発電機の特許競争力で2023年に初めて首位になった。
# 2番目の文： 欧州最大手のベスタスを抱えるデンマークを逆転した。
# 3番目の文： 中国勢はコスト削減につながる風車の大型化で技術力を高めており、6割に達する世界シェアのさらなる拡大が見込まれる。
# 4番目の文： 太陽光パネルに続き、風力発電機でも価格攻勢を強めており、米欧は脱炭素の関連産業の保護に動き始めた。

# %% [markdown]
# 単語分割の結果を確認する。

# %%
words = [token.text for token in doc]

print("==== 単語分割:Text====")
print(words)
# Out:
# ==== 単語分割:Text====
# ['中国', 'が', '風力', '発電機', 'の', '特許', '競争力', 'で', '2023', '年', 'に', '初めて', '首位', 'に', 'なっ', 'た', '。', '欧州', '最大手', 'の', 'ベスタス', 'を', '抱える', 'デンマーク', 'を', '逆転', 'し', 'た', '。', '中国', '勢', 'は', 'コスト削減', 'に', 'つながる', '風車', 'の', '大型', '化', 'で', '技術力', 'を', '高め', 'て', 'おり', '、', '6', '割', 'に', '達する', '世界', 'シェア', 'の', 'さらなる', '拡大', 'が', '見込ま', 'れる', '。', '太陽光', 'パネル', 'に', '続き', '、', '風力', '発電機', 'で', 'も', '価格', '攻勢', 'を', '強め', 'て', 'おり', '、', '米欧', 'は', '脱炭素', 'の', '関連', '産業', 'の', '保護', 'に', '動き始め', 'た', '。']

# %% [markdown]
# 最初の文の単語分割結果を確認する。

# %%
sentences = list(doc.sents)
first_sentence = sentences[0]
second_sentence = sentences[1]
third_sentence = sentences[2]
forth_sentence = sentences[3]

words_of_first_sentence = [token.text for token in first_sentence]
words_of_second_sentence = [token.text for token in second_sentence]
words_of_third_sentence = [token.text for token in third_sentence]
words_of_forth_sentence = [token.text for token in forth_sentence]

print(words_of_first_sentence)
print(words_of_second_sentence)
print(words_of_third_sentence)
print(words_of_forth_sentence)
# Out:
# ['中国', 'が', '風力', '発電機', 'の', '特許', '競争力', 'で', '2023', '年', 'に', '初めて', '首位', 'に', 'なっ', 'た', '。']
# ['欧州', '最大手', 'の', 'ベスタス', 'を', '抱える', 'デンマーク', 'を', '逆転', 'し', 'た', '。']
# ['中国', '勢', 'は', 'コスト削減', 'に', 'つながる', '風車', 'の', '大型', '化', 'で', '技術力', 'を', '高め', 'て', 'おり', '、', '6', '割', 'に', '達する', '世界', 'シェア', 'の', 'さらなる', '拡大', 'が', '見込ま', 'れる', '。']
# ['太陽光', 'パネル', 'に', '続き', '、', '風力', '発電機', 'で', 'も', '価格', '攻勢', 'を', '強め', 'て', 'おり', '、', '米欧', 'は', '脱炭素', 'の', '関連', '産業', 'の', '保護', 'に', '動き始め', 'た', '。']

# %% [markdown]
# ## 形態素解析

# %%
print("==== 形態素解析:first_sentence (単語表記｜原型｜品詞)====")
for token in first_sentence:
    print(token.text, token.lemma_, token.pos_)

print("==== 形態素解析:second_sentence (単語表記｜原型｜品詞)====")
for token in second_sentence:
    print(token.text, token.lemma_, token.pos_)

print("==== 形態素解析:third_sentence (単語表記｜原型｜品詞)====")
for token in third_sentence:
    print(token.text, token.lemma_, token.pos_)

print("==== 形態素解析:forth_sentence (単語表記｜原型｜品詞)====")
for token in forth_sentence:
    print(token.text, token.lemma_, token.pos_)
# Out:
# ==== 形態素解析:first_sentence (単語表記｜原型｜品詞)====
# 中国 中国 PROPN
# が が ADP
# 風力 風力 NOUN
# 発電機 発電機 NOUN
# の の ADP
# 特許 特許 NOUN
# 競争力 競争力 NOUN
# で で ADP
# 2023 2023 NUM
# 年 年 NOUN
# に に ADP
# 初めて 初めて ADV
# 首位 首位 NOUN
# に に ADP
# なっ なる VERB
# た た AUX
# 。 。 PUNCT
# ==== 形態素解析:second_sentence (単語表記｜原型｜品詞)====
# 欧州 欧州 PROPN
# 最大手 最大手 NOUN
# の の ADP
# ベスタス ベスタス NOUN
# を を ADP
# 抱える 抱える VERB
# デンマーク デンマーク PROPN
# を を ADP
# 逆転 逆転 VERB
# し する AUX
# た た AUX
# 。 。 PUNCT
# ==== 形態素解析:third_sentence (単語表記｜原型｜品詞)====
# 中国 中国 PROPN
# 勢 勢 NOUN
# は は ADP
# コスト削減 コスト削減 ADJ
# に に AUX
# つながる つながる VERB
# 風車 風車 NOUN
# の の ADP
# 大型 大型 NOUN
# 化 化 NOUN
# で で ADP
# 技術力 技術力 NOUN
# を を ADP
# 高め 高める VERB
# て て SCONJ
# おり おる VERB
# 、 、 PUNCT
# 6 6 NUM
# 割 割 NOUN
# に に ADP
# 達する 達する VERB
# 世界 世界 NOUN
# シェア シェア NOUN
# の の ADP
# さらなる さらなる ADJ
# 拡大 拡大 NOUN
# が が ADP
# 見込ま 見込む VERB
# れる れる AUX
# 。 。 PUNCT
# ==== 形態素解析:forth_sentence (単語表記｜原型｜品詞)====
# 太陽光 太陽光 NOUN
# パネル パネル NOUN
# に に ADP
# 続き 続く VERB
# 、 、 PUNCT
# 風力 風力 NOUN
# 発電機 発電機 NOUN
# で で ADP
# も も ADP
# 価格 価格 NOUN
# 攻勢 攻勢 NOUN
# を を ADP
# 強め 強める VERB
# て て SCONJ
# おり おる VERB
# 、 、 PUNCT
# 米欧 米欧 NOUN
# は は ADP
# 脱炭素 脱炭素 NOUN
# の の ADP
# 関連 関連 NOUN
# 産業 産業 NOUN
# の の ADP
# 保護 保護 NOUN
# に に ADP
# 動き始め 動き始める VERB
# た た AUX
# 。 。 PUNCT

# %% [markdown]
# ## 構文解析
# 依存構造解析の結果を確認する。

# %%
print("==== 構文解析:first_sentence (単語表記--依存関係ラベル-->主辞)====")
for token in first_sentence:
    modifier = token.text
    dependency_relation = token.dep_
    head = token.head.text
    print(f'{modifier} --{dependency_relation}--> {head}')

print("==== 構文解析:second_sentence (単語表記--依存関係ラベル-->主辞)====")
for token in second_sentence:
    modifier = token.text
    dependency_relation = token.dep_
    head = token.head.text
    print(f'{modifier} --{dependency_relation}--> {head}')

print("==== 構文解析:third_sentence (単語表記--依存関係ラベル-->主辞)====")
for token in third_sentence:
    modifier = token.text
    dependency_relation = token.dep_
    head = token.head.text
    print(f'{modifier} --{dependency_relation}--> {head}')

print("==== 構文解析:forth_sentence (単語表記--依存関係ラベル-->主辞)====")
for token in forth_sentence:
    modifier = token.text
    dependency_relation = token.dep_
    head = token.head.text
    print(f'{modifier} --{dependency_relation}--> {head}')
# Out:
# ==== 構文解析:first_sentence (単語表記--依存関係ラベル-->主辞)====
# 中国 --nsubj--> なっ
# が --case--> 中国
# 風力 --compound--> 発電機
# 発電機 --nmod--> 競争力
# の --case--> 発電機
# 特許 --compound--> 競争力
# 競争力 --obl--> なっ
# で --case--> 競争力
# 2023 --nummod--> 年
# 年 --obl--> なっ
# に --case--> 年
# 初めて --advmod--> なっ
# 首位 --obl--> なっ
# に --case--> 首位
# なっ --ROOT--> なっ
# た --aux--> なっ
# 。 --punct--> なっ
# ==== 構文解析:second_sentence (単語表記--依存関係ラベル-->主辞)====
# 欧州 --compound--> 最大手
# 最大手 --nmod--> ベスタス
# の --case--> 最大手
# ベスタス --obj--> 抱える
# を --case--> ベスタス
# 抱える --acl--> デンマーク
# デンマーク --obj--> 逆転
# を --case--> デンマーク
# 逆転 --ROOT--> 逆転
# し --aux--> 逆転
# た --aux--> 逆転
# 。 --punct--> 逆転
# ==== 構文解析:third_sentence (単語表記--依存関係ラベル-->主辞)====
# 中国 --compound--> 勢
# 勢 --nsubj--> 高め
# は --case--> 勢
# コスト削減 --advcl--> つながる
# に --aux--> コスト削減
# つながる --acl--> 風車
# 風車 --nmod--> 化
# の --case--> 風車
# 大型 --compound--> 化
# 化 --obl--> 高め
# で --case--> 化
# 技術力 --obj--> 高め
# を --case--> 技術力
# 高め --advcl--> 見込ま
# て --mark--> 高め
# おり --fixed--> て
# 、 --punct--> 高め
# 6 --nummod--> 割
# 割 --obl--> 達する
# に --case--> 割
# 達する --advcl--> 見込ま
# 世界 --compound--> シェア
# シェア --nmod--> 拡大
# の --case--> シェア
# さらなる --amod--> 拡大
# 拡大 --nsubj--> 見込ま
# が --case--> 拡大
# 見込ま --ROOT--> 見込ま
# れる --aux--> 見込ま
# 。 --punct--> 見込ま
# ==== 構文解析:forth_sentence (単語表記--依存関係ラベル-->主辞)====
# 太陽光 --compound--> パネル
# パネル --obl--> 続き
# に --case--> パネル
# 続き --advcl--> 強め
# 、 --punct--> 続き
# 風力 --compound--> 発電機
# 発電機 --obl--> 強め
# で --case--> 発電機
# も --case--> 発電機
# 価格 --compound--> 攻勢
# 攻勢 --obj--> 強め
# を --case--> 攻勢
# 強め --advcl--> 動き始め
# て --mark--> 強め
# おり --fixed--> て
# 、 --punct--> 強め
# 米欧 --nsubj--> 動き始め
# は --case--> 米欧
# 脱炭素 --nmod--> 産業
# の --case--> 脱炭素
# 関連 --compound--> 産業
# 産業 --nmod--> 保護
# の --case--> 産業
# 保護 --obl--> 動き始め
# に --case--> 保護
# 動き始め --ROOT--> 動き始め
# た --aux--> 動き始め
# 。 --punct--> 動き始め

# %% [markdown]
# 依存構文木を可視化モジュールdisplacyを使って確認する。
#
# displacyの詳細は以下のリンクで確認できる：https://spacy.io/usage/visualizers

# %%
svg = displacy.render(first_sentence,
                      style="dep",
                      options={'compact':True},
                      jupyter=True)

svg2 = displacy.render(second_sentence,
                      style="dep",
                      options={'compact':True},
                      jupyter=True)

svg3 = displacy.render(third_sentence,
                      style="dep",
                      options={'compact':True},
                      jupyter=True)

svg4 = displacy.render(forth_sentence,
                      style="dep",
                      options={'compact':True},
                      jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ja" id="8bf777f9f58448729af6fe9f734b13d6-0" class="displacy" width="2450" height="587.0" direction="ltr" style="max-width: none; height: 587.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">中国</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">が</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">風力</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">発電機</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">の</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">特許</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">競争力</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">で</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">2023</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">年</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">に</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">初めて</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">首位</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">に</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">なっ</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">た。</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">AUX</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8bf777f9f58448729af6fe9f734b13d6-0-0" stroke-width="2px" d="M62,452.0 62,302.0 2150.0,302.0 2150.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8bf777f9f58448729af6fe9f734b13d6-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,454.0 L58,446.0 66,446.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8bf777f9f58448729af6fe9f734b13d6-0-1" stroke-width="2px" d="M62,452.0 62,427.0 185.0,427.0 185.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8bf777f9f58448729af6fe9f734b13d6-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M185.0,454.0 L189.0,446.0 181.0,446.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8bf777f9f58448729af6fe9f734b13d6-0-2" stroke-width="2px" d="M362,452.0 362,427.0 485.0,427.0 485.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8bf777f9f58448729af6fe9f734b13d6-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M362,454.0 L358,446.0 366,446.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8bf777f9f58448729af6fe9f734b13d6-0-3" stroke-width="2px" d="M512,452.0 512,402.0 938.0,402.0 938.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8bf777f9f58448729af6fe9f734b13d6-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M512,454.0 L508,446.0 516,446.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8bf777f9f58448729af6fe9f734b13d6-0-4" stroke-width="2px" d="M512,452.0 512,427.0 635.0,427.0 635.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8bf777f9f58448729af6fe9f734b13d6-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M635.0,454.0 L639.0,446.0 631.0,446.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8bf777f9f58448729af6fe9f734b13d6-0-5" stroke-width="2px" d="M812,452.0 812,427.0 935.0,427.0 935.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8bf777f9f58448729af6fe9f734b13d6-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M812,454.0 L808,446.0 816,446.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8bf777f9f58448729af6fe9f734b13d6-0-6" stroke-width="2px" d="M962,452.0 962,327.0 2147.0,327.0 2147.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-sp
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ja" id="59477818cb7f4172af0741a6d4662024-0" class="displacy" width="1700" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">欧州</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">最大手</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">の</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">ベスタス</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">を</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">抱える</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">デンマーク</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">を</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">逆転</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">し</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">た。</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">AUX</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-59477818cb7f4172af0741a6d4662024-0-0" stroke-width="2px" d="M62,152.0 62,127.0 197.0,127.0 197.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-59477818cb7f4172af0741a6d4662024-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,154.0 L58,146.0 66,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-59477818cb7f4172af0741a6d4662024-0-1" stroke-width="2px" d="M212,152.0 212,102.0 500.0,102.0 500.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-59477818cb7f4172af0741a6d4662024-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,154.0 L208,146.0 216,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-59477818cb7f4172af0741a6d4662024-0-2" stroke-width="2px" d="M212,152.0 212,127.0 347.0,127.0 347.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-59477818cb7f4172af0741a6d4662024-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M347.0,154.0 L351.0,146.0 343.0,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-59477818cb7f4172af0741a6d4662024-0-3" stroke-width="2px" d="M512,152.0 512,102.0 800.0,102.0 800.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-59477818cb7f4172af0741a6d4662024-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M512,154.0 L508,146.0 516,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-59477818cb7f4172af0741a6d4662024-0-4" stroke-width="2px" d="M512,152.0 512,127.0 647.0,127.0 647.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-59477818cb7f4172af0741a6d4662024-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M647.0,154.0 L651.0,146.0 643.0,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-59477818cb7f4172af0741a6d4662024-0-5" stroke-width="2px" d="M812,152.0 812,127.0 947.0,127.0 947.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-59477818cb7f4172af0741a6d4662024-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M812,154.0 L808,146.0 816,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-59477818cb7f4172af0741a6d4662024-0-6" stroke-width="2px" d="M962,152.0 962,102.0 1250.0,102.0 1250.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-59477818cb7f4172af0741a6d4662024-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M962,154.0 L958,146.0 966,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-59477818cb7f4172af0741a6d4662024-0-7" stroke-width="2px" d="M962,152.0 962,127.0 1097.0,127.0 1097.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-59477818cb7f4172af0741a6d4662024-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1097.0,154.0 L1101.0,146.0 1093.0,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-59477818cb7f4172af0741a6d4662024-0-8" stroke-width="2px" d="M1262,152.0 1262,127.0 1397.0,127.0 1397.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-59477818cb7
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ja" id="d4a8c370ddbc4069b335e8bfd91789a3-0" class="displacy" width="4250" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">中国</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">勢</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">は</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">コスト削減</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">に</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">つながる</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">風車</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">の</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">大型</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">化</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">で</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">技術力</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">を</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">高め</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">て</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">おり、</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">6</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">割</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">に</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">達する</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">世界</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">シェア</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">の</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">さらなる</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">拡大</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3800">が</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3950">見込ま</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="4100">れる。</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4100">AUX</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d4a8c370ddbc4069b335e8bfd91789a3-0-0" stroke-width="2px" d="M62,302.0 62,277.0 191.0,277.0 191.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d4a8c370ddbc4069b335e8bfd91789a3-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,304.0 L58,296.0 66,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d4a8c370ddbc4069b335e8bfd91789a3-0-1" stroke-width="2px" d="M212,302.0 212,202.0 2000.0,202.0 2000.0,302.0" fill="none" stroke="currentColor"/>
#     <tex
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ja" id="2787ae04d7ca43b99bc9f67c4d543906-0" class="displacy" width="3800" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">太陽光</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">パネル</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">に</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">続き、</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">風力</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">発電機</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">で</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">も</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">価格</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">攻勢</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">を</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">強め</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">て</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">おり、</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">米欧</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">は</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">脱炭素</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">の</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">関連</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">産業</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">の</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">保護</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">に</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">動き始め</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">た。</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">AUX</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2787ae04d7ca43b99bc9f67c4d543906-0-0" stroke-width="2px" d="M62,302.0 62,277.0 191.0,277.0 191.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2787ae04d7ca43b99bc9f67c4d543906-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,304.0 L58,296.0 66,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2787ae04d7ca43b99bc9f67c4d543906-0-1" stroke-width="2px" d="M212,302.0 212,252.0 494.0,252.0 494.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2787ae04d7ca43b99bc9f67c4d543906-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,304.0 L208,296.0 216,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2787ae04d7ca43b99bc9f67c4d543906-0-2" stroke-width="2px" d="M212,302.0 212,277.0 341.0,277.0 341.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2787ae04d7ca43b99bc9f67c4d543906-0-2" class="displacy-label" star

# %% [markdown]
# 依存関係ラベルの詳細は以下のコマンドにより確認できる：

# %%
spacy.explain('nsubj')
# Out:
# 'nominal subject'

# %% [markdown]
# ## 固有表現認識
# 固有表現認識（NER）は、テキストデータから人名、地名、組織名など特定の情報を抽出する自然言語処理のタスクです。

# %%
print("==== 固有表現認識 (NER):first_sentence ====")
for ent in first_sentence.ents:
    print(ent.text, ent.label_)

print("==== 固有表現認識 (NER):second_sentence ====")
for ent in second_sentence.ents:
    print(ent.text, ent.label_)

print("==== 固有表現認識 (NER):third_sentence ====")
for ent in third_sentence.ents:
    print(ent.text, ent.label_)

print("==== 固有表現認識 (NER):forth_sentence ====")
for ent in forth_sentence.ents:
    print(ent.text, ent.label_)
# Out:
# ==== 固有表現認識 (NER):first_sentence ====
# 中国 Country
# 2023年 Date
# 首位 Rank
# ==== 固有表現認識 (NER):second_sentence ====
# 欧州最大手 International_Organization
# デンマーク Country
# ==== 固有表現認識 (NER):third_sentence_2 ====
# 中国勢 Military
# 6割 Percent
# ==== 固有表現認識 (NER):forth_sentence_2 ====

# %% [markdown]
# displacyによる可視化：

# %%
svg = displacy.render(first_sentence,
                      style="ent",
                      jupyter=True)
svg2 = displacy.render(second_sentence,
                      style="ent",
                      jupyter=True)
svg3 = displacy.render(third_sentence,
                      style="ent",
                      jupyter=True)
svg4 = displacy.render(forth_sentence,
                      style="ent",
                      jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     中国
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Country</span>
# </mark>
# が風力発電機の特許競争力で
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2023年
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Date</span>
# </mark>
# に初めて
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     首位
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Rank</span>
# </mark>
# になった。</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     欧州最大手
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">International_Organization</span>
# </mark>
# のベスタスを抱える
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     デンマーク
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Country</span>
# </mark>
# を逆転した。</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     中国勢
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Military</span>
# </mark>
# はコスト削減につながる風車の大型化で技術力を高めており、
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6割
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Percent</span>
# </mark>
# に達する世界シェアのさらなる拡大が見込まれる。</div></span>
# /opt/anaconda3/lib/python3.11/site-packages/spacy/displacy/__init__.py:213: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">太陽光パネルに続き、風力発電機でも価格攻勢を強めており、米欧は脱炭素の関連産業の保護に動き始めた。</div></span>

# %%
#英語ver
nlp_en = spacy.load('en_core_web_sm')

# %%
text_en = "Democratic President Joe Biden's family has urged him to ignore calls to step aside following his disastrous debate against Republican Donald Trump. He spent Sunday with relatives at a presidential retreat where they encouraged him to keep fighting, according to the BBC's US partner CBS News. Anxiety has gripped sections of his party following a rambling and at times incoherent performance in Atlanta."

# %%
doc_en = nlp_en(text_en)

# %%
print("==== 文分割:Text_en====")
for i, sent in enumerate(doc_en.sents):
    print(f'{i+1}番目の文：', sent)
# Out:
# ==== 文分割:Text_en====
# 1番目の文： Democratic President Joe Biden's family has urged him to ignore calls to step aside following his disastrous debate against Republican Donald Trump.
# 2番目の文： He spent Sunday with relatives at a presidential retreat where they encouraged him to keep fighting, according to the BBC's US partner CBS News.
# 3番目の文： Anxiety has gripped sections of his party following a rambling and at times incoherent performance in Atlanta.

# %%
words = [token.text for token in doc_en]

print("==== 単語分割:Text====")
print(words)
# Out:
# ==== 単語分割:Text====
# ['Democratic', 'President', 'Joe', 'Biden', "'s", 'family', 'has', 'urged', 'him', 'to', 'ignore', 'calls', 'to', 'step', 'aside', 'following', 'his', 'disastrous', 'debate', 'against', 'Republican', 'Donald', 'Trump', '.', 'He', 'spent', 'Sunday', 'with', 'relatives', 'at', 'a', 'presidential', 'retreat', 'where', 'they', 'encouraged', 'him', 'to', 'keep', 'fighting', ',', 'according', 'to', 'the', 'BBC', "'s", 'US', 'partner', 'CBS', 'News', '.', 'Anxiety', 'has', 'gripped', 'sections', 'of', 'his', 'party', 'following', 'a', 'rambling', 'and', 'at', 'times', 'incoherent', 'performance', 'in', 'Atlanta', '.']

# %%
sentences = list(doc_en.sents)
first_sentence = sentences[0]
second_sentence = sentences[1]
third_sentence = sentences[2]

words_of_first_sentence = [token.text for token in first_sentence]
words_of_second_sentence = [token.text for token in second_sentence]
words_of_third_sentence = [token.text for token in third_sentence]

print(words_of_first_sentence)
print(words_of_second_sentence)
print(words_of_third_sentence)
# Out:
# ['Democratic', 'President', 'Joe', 'Biden', "'s", 'family', 'has', 'urged', 'him', 'to', 'ignore', 'calls', 'to', 'step', 'aside', 'following', 'his', 'disastrous', 'debate', 'against', 'Republican', 'Donald', 'Trump', '.']
# ['He', 'spent', 'Sunday', 'with', 'relatives', 'at', 'a', 'presidential', 'retreat', 'where', 'they', 'encouraged', 'him', 'to', 'keep', 'fighting', ',', 'according', 'to', 'the', 'BBC', "'s", 'US', 'partner', 'CBS', 'News', '.']
# ['Anxiety', 'has', 'gripped', 'sections', 'of', 'his', 'party', 'following', 'a', 'rambling', 'and', 'at', 'times', 'incoherent', 'performance', 'in', 'Atlanta', '.']

# %%
print("==== 形態素解析:first_sentence (単語表記｜原型｜品詞)====")
for token in first_sentence:
    print(token.text, token.lemma_, token.pos_)

print("==== 形態素解析:second_sentence (単語表記｜原型｜品詞)====")
for token in second_sentence:
    print(token.text, token.lemma_, token.pos_)

print("==== 形態素解析:third_sentence (単語表記｜原型｜品詞)====")
for token in third_sentence:
    print(token.text, token.lemma_, token.pos_)
# Out:
# ==== 形態素解析:first_sentence (単語表記｜原型｜品詞)====
# Democratic democratic ADJ
# President President PROPN
# Joe Joe PROPN
# Biden Biden PROPN
# 's 's PART
# family family NOUN
# has have AUX
# urged urge VERB
# him he PRON
# to to PART
# ignore ignore VERB
# calls call NOUN
# to to PART
# step step VERB
# aside aside ADV
# following follow VERB
# his his PRON
# disastrous disastrous ADJ
# debate debate NOUN
# against against ADP
# Republican Republican PROPN
# Donald Donald PROPN
# Trump Trump PROPN
# . . PUNCT
# ==== 形態素解析:second_sentence (単語表記｜原型｜品詞)====
# He he PRON
# spent spend VERB
# Sunday Sunday PROPN
# with with ADP
# relatives relative NOUN
# at at ADP
# a a DET
# presidential presidential ADJ
# retreat retreat NOUN
# where where SCONJ
# they they PRON
# encouraged encourage VERB
# him he PRON
# to to PART
# keep keep VERB
# fighting fight VERB
# , , PUNCT
# according accord VERB
# to to ADP
# the the DET
# BBC BBC PROPN
# 's 's PART
# US US PROPN
# partner partner NOUN
# CBS CBS PROPN
# News News PROPN
# . . PUNCT
# ==== 形態素解析:third_sentence (単語表記｜原型｜品詞)====
# Anxiety anxiety NOUN
# has have AUX
# gripped grip VERB
# sections section NOUN
# of of ADP
# his his PRON
# party party NOUN
# following follow VERB
# a a DET
# rambling rambling NOUN
# and and CCONJ
# at at ADP
# times time NOUN
# incoherent incoherent ADJ
# performance performance NOUN
# in in ADP
# Atlanta Atlanta PROPN
# . . PUNCT

# %%
print("==== 構文解析:first_sentence (単語表記--依存関係ラベル-->主辞)====")
for token in first_sentence:
    modifier = token.text
    dependency_relation = token.dep_
    head = token.head.text
    print(f'{modifier} --{dependency_relation}--> {head}')

print("==== 構文解析:second_sentence (単語表記--依存関係ラベル-->主辞)====")
for token in second_sentence:
    modifier = token.text
    dependency_relation = token.dep_
    head = token.head.text
    print(f'{modifier} --{dependency_relation}--> {head}')

print("==== 構文解析:third_sentence (単語表記--依存関係ラベル-->主辞)====")
for token in third_sentence:
    modifier = token.text
    dependency_relation = token.dep_
    head = token.head.text
    print(f'{modifier} --{dependency_relation}--> {head}')
# Out:
# ==== 構文解析:first_sentence (単語表記--依存関係ラベル-->主辞)====
# Democratic --amod--> President
# President --compound--> Biden
# Joe --compound--> Biden
# Biden --poss--> family
# 's --case--> Biden
# family --nsubj--> urged
# has --aux--> urged
# urged --ROOT--> urged
# him --dobj--> urged
# to --aux--> ignore
# ignore --xcomp--> urged
# calls --dobj--> ignore
# to --aux--> step
# step --relcl--> calls
# aside --advmod--> step
# following --prep--> ignore
# his --poss--> debate
# disastrous --amod--> debate
# debate --pobj--> following
# against --prep--> debate
# Republican --compound--> Trump
# Donald --compound--> Trump
# Trump --pobj--> against
# . --punct--> urged
# ==== 構文解析:second_sentence (単語表記--依存関係ラベル-->主辞)====
# He --nsubj--> spent
# spent --ROOT--> spent
# Sunday --npadvmod--> spent
# with --prep--> spent
# relatives --pobj--> with
# at --prep--> relatives
# a --det--> retreat
# presidential --amod--> retreat
# retreat --pobj--> at
# where --advmod--> encouraged
# they --nsubj--> encouraged
# encouraged --relcl--> retreat
# him --dobj--> encouraged
# to --aux--> keep
# keep --xcomp--> encouraged
# fighting --xcomp--> keep
# , --punct--> spent
# according --prep--> spent
# to --prep--> according
# the --det--> BBC
# BBC --poss--> partner
# 's --case--> BBC
# US --compound--> partner
# partner --compound--> News
# CBS --compound--> News
# News --pobj--> to
# . --punct--> spent
# ==== 構文解析:third_sentence (単語表記--依存関係ラベル-->主辞)====
# Anxiety --nsubj--> gripped
# has --aux--> gripped
# gripped --ROOT--> gripped
# sections --dobj--> gripped
# of --prep--> sections
# his --poss--> party
# party --pobj--> of
# following --prep--> gripped
# a --det--> rambling
# rambling --pobj--> following
# and --cc--> following
# at --conj--> following
# times --pobj--> at
# incoherent --amod--> performance
# performance --pobj--> at
# in --prep--> performance
# Atlanta --pobj--> in
# . --punct--> gripped

# %%
svg = displacy.render(first_sentence,
                      style="dep",
                      options={'compact':True},
                      jupyter=True)

svg2 = displacy.render(second_sentence,
                      style="dep",
                      options={'compact':True},
                      jupyter=True)

svg3 = displacy.render(third_sentence,
                      style="dep",
                      options={'compact':True},
                      jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="223b9f6f7e18497882245207f543420d-0" class="displacy" width="3500" height="362.0" direction="ltr" style="max-width: none; height: 362.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Democratic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">President</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">Joe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">Biden</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">family</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">urged</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">him</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">ignore</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">calls</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">step</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">aside</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">following</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">his</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">disastrous</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">debate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">against</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">Republican</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">Donald</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">Trump.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-223b9f6f7e18497882245207f543420d-0-0" stroke-width="2px" d="M62,227.0 62,202.0 194.0,202.0 194.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-223b9f6f7e18497882245207f543420d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,229.0 L58,221.0 66,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-223b9f6f7e18497882245207f543420d-0-1" stroke-width="2px" d="M212,227.0 212,177.0 497.0,177.0 497.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-223b9f6f7e18497882245207f543420d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,229.0 L208,221.0 216,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-223b9f6f7e18497882245207f543420d-0-2" stroke-width="2px" d="M362,227.0 362,202.0 494.0,202.0 494.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-223b9f6f7e18497882245207f543420d-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M362,229.0 L358,221.0 366,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-223b9f6f7e18497882245207f543420d-0-3" stroke-width="2px" d="M512,227.0 512,177.0 797.0,177.0 797.0,227.0" fill="none" stroke="curren
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="24f6d8d0d8a34021a85db809eee49527-0" class="displacy" width="3800" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">He</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">spent</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">Sunday</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">relatives</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">presidential</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">retreat</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">where</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">they</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">encouraged</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">him</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">keep</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">fighting,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">according</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">BBC</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">US</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">partner</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">CBS</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">News.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-24f6d8d0d8a34021a85db809eee49527-0-0" stroke-width="2px" d="M62,302.0 62,277.0 191.0,277.0 191.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-24f6d8d0d8a34021a85db809eee49527-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,304.0 L58,296.0 66,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-24f6d8d0d8a34021a85db809eee49527-0-1" stroke-width="2px" d="M212,302.0 212,277.0 341.0,277.0 341.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-24f6d8d0d8a34021a85db809eee49527-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">npadvmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M341.0,304.0 L345.0,296.0 337.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-24f6d8d0d8a34021a85db809eee49527-0-2" stroke-width="2px" d="M212,302.0 212,252.0 494.0,252.0 494.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textP
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a1ee8af6745f423b8ad9b24549992f95-0" class="displacy" width="2600" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Anxiety</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">gripped</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">sections</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">his</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">party</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">following</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">rambling</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">times</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">incoherent</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">performance</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">Atlanta.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a1ee8af6745f423b8ad9b24549992f95-0-0" stroke-width="2px" d="M62,302.0 62,252.0 344.0,252.0 344.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a1ee8af6745f423b8ad9b24549992f95-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,304.0 L58,296.0 66,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a1ee8af6745f423b8ad9b24549992f95-0-1" stroke-width="2px" d="M212,302.0 212,277.0 341.0,277.0 341.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a1ee8af6745f423b8ad9b24549992f95-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,304.0 L208,296.0 216,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a1ee8af6745f423b8ad9b24549992f95-0-2" stroke-width="2px" d="M362,302.0 362,277.0 491.0,277.0 491.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a1ee8af6745f423b8ad9b24549992f95-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M491.0,304.0 L495.0,296.0 487.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a1ee8af6745f423b8ad9b24549992f95-0-3" stroke-width="2px" d="M512,302.0 512,277.0 641.0,277.0 641.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a1ee8af6745f423b8ad9b24549992f95-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M641.0,304.0 L645.0,296.0 637.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a1ee8af6745f423b8ad9b24549992f95-0-4" stroke-width="2px" d="M812,302.0 812,277.0 941.0,277.0 941.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a1ee8af6745f423b8ad9b24549992f95-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M812,304.0 L808,296.0 816,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a1ee8af6745f423b8ad9b24549992f95-0-5" stroke-width="2px" d="M662,302.0 662,252.0 944.0,252.0 944.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a1ee8af6745f423b8ad9b24549992f95-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M944.0,304.0 L948.0,296.0 94

# %%
print("==== 固有表現認識 (NER):first_sentence ====")
for ent in first_sentence.ents:
    print(ent.text, ent.label_)

print("==== 固有表現認識 (NER):second_sentence ====")
for ent in second_sentence.ents:
    print(ent.text, ent.label_)

print("==== 固有表現認識 (NER):third_sentence ====")
for ent in third_sentence.ents:
    print(ent.text, ent.label_)
# Out:
# ==== 固有表現認識 (NER):first_sentence ====
# Democratic NORP
# Joe Biden's PERSON
# Republican NORP
# Donald Trump PERSON
# ==== 固有表現認識 (NER):second_sentence ====
# Sunday DATE
# BBC ORG
# US GPE
# CBS News ORG
# ==== 固有表現認識 (NER):third_sentence ====
# Atlanta GPE

# %%
svg = displacy.render(first_sentence,
                      style="ent",
                      jupyter=True)
svg2 = displacy.render(second_sentence,
                      style="ent",
                      jupyter=True)
svg3 = displacy.render(third_sentence,
                      style="ent",
                      jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Democratic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Joe Biden's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  family has urged him to ignore calls to step aside following his disastrous debate against
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Republican
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Donald Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">He spent
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sunday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  with relatives at a presidential retreat where they encouraged him to keep fighting, according to the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BBC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  partner
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CBS News
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Anxiety has gripped sections of his party following a rambling and at times incoherent performance in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Atlanta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .</div></span>
